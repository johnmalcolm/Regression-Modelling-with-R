# %% [markdown]
# # Dont just compare the R2, S & t(b1) values! Visually examine the data!
# ## 2.8 COMPARE

# %%
install.packages("tidyverse")
require(tidyverse)

compare_df <- read.table("/Users/jmanderson/statistics/02_intro-to-regression/ARM by Iain - Exercises/data/compare.csv", 
                       sep=",", header = T, stringsAsFactors = F)
# Out:
# The downloaded binary packages are in
# 	/var/folders/tz/875z4smn2sz0kndfn6lyfvf40000gn/T//RtmpqMkpLx/downloaded_packages
# Loading required package: tidyverse
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   0.8.5
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
head(compare_df)
# Out:
#   Y    X1   X2   X3   X4
# 1 0.40 1.02 0.02 1.12 0.30
# 2 1.35 0.91 0.11 1.01 0.38
# 3 2.27 1.73 0.23 1.73 0.38
# 4 3.22 2.99 0.89 2.69 0.77
# 5 3.37 1.08 1.18 1.98 0.85
# 6 3.43 2.93 1.33 2.53 0.75

# %%
plot(Y~X1, data=compare_df)
plot(Y~X2, data=compare_df)
plot(Y~X3, data=compare_df)
plot(Y~X4, data=compare_df)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# *Things are already not looking too reassuring!*
#
# (a) Fit a simple linear regression using Xi as the predictor . Make a note of the values of the regression standard error, s, the coefficient of determination, R2, and the t-statistic for the slope parameter, Also construct a scatter plot of Y (vertical) versus X (horizontal) and add the least squares regression line to the plot

# %%
lmX1 = lm(Y~X1, compare_df)
summary(lmX1)
# Out:
# Call:
# lm(formula = Y ~ X1, data = compare_df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.9784 -0.6855  0.2459  0.7101  2.0322
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.57049    0.37571    4.18 0.000123 ***
# X1           1.07647    0.07611   14.14  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.07 on 48 degrees of freedom
# Multiple R-squared:  0.8065,	Adjusted R-squared:  0.8024
# F-statistic:   200 on 1 and 48 DF,  p-value: < 2.2e-16

# %%
plot(Y~X1, data=compare_df)
abline(lmX1)
# Out:
# plot without title

# %% [markdown]
# (b) Repeat part (a), but this time use X2 as the predictor. Do the values of s, R2, and 1*6,1 suggest a worse or better fit than the model from part (a)? Does the visual appearance of the scatterplot for the X2 model confirm or contradict the numerical findings?

# %%
lmX2 = lm(Y~X2, compare_df)
summary(lmX2)

plot(Y~X2, data=compare_df)
abline(lmX2)
# Out:
# Call:
# lm(formula = Y ~ X2, data = compare_df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.44514 -0.34997  0.03797  0.50361  2.30698
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.42555    0.30323   7.999 2.21e-10 ***
# X2           0.88722    0.05906  15.023  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.019 on 48 degrees of freedom
# Multiple R-squared:  0.8246,	Adjusted R-squared:  0.821
# F-statistic: 225.7 on 1 and 48 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# From a visual interpretations of this graph, I would suggests there is bias in theses estimates. The assumption of zero homoscedasticity (constant variance) is clearly not present in the residuals.

# %% [markdown]
# (c) Repeat part (a), but this time use X3 as the predictor. Do the values of s, R2, and tb1 I suggest a worse or better fit than the model from part (a)? Does the visual appearance of the scatterplot for the X3 model confirm or contradict the numerical findings?

# %%
lmX3 = lm(Y~X3, compare_df)
summary(lmX3)

plot(Y~X3, data=compare_df)
abline(lmX3)
# Out:
# Call:
# lm(formula = Y ~ X3, data = compare_df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8241 -0.5524 -0.1154  0.4667  2.1975
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.11793    0.32146   6.589 3.15e-08 ***
# X3           0.98766    0.06576  15.020  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.019 on 48 degrees of freedom
# Multiple R-squared:  0.8246,	Adjusted R-squared:  0.8209
# F-statistic: 225.6 on 1 and 48 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# From a visual interpretations of this graph, I would suggests there is bias in theses estimates.
#
# Firstly the errors in the data suggest that the mean of residuals across the regression line is not equal to zero. At several points on the graph there is a clear skew, with the residuals in the left and right corners of the graph mostly beneath the regression line. This suggests the zero mean assumption is not upheld.
#
# The second assumption that may be broken here is the constant variance, again we see a large difference in the width of residual error between sections of the plot.

# %% [markdown]
# (d) Repeat part (a), but this time use X4 as the predictor. Do the values of s, R2, and tb1 I suggest a worse or better fit than the model from part (a)? Does the visual appearance of the scatterplot for the X4 model confirm or contradict the numerical findings?

# %%
lmX4 = lm(Y~X4, compare_df)
summary(lmX4)

plot(Y~X4, data=compare_df)
abline(lmX4)
# Out:
# Call:
# lm(formula = Y ~ X4, data = compare_df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.7266 -0.6456 -0.1058  1.0528  1.7842
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.85659    0.27838   10.26 1.08e-13 ***
# X4           0.90016    0.05993   15.02  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.019 on 48 degrees of freedom
# Multiple R-squared:  0.8245,	Adjusted R-squared:  0.8209
# F-statistic: 225.6 on 1 and 48 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# This one fails them all, zero mean, normality, independance and constant variance. Just look at it.
